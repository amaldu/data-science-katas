# %%
# %reload_ext sql

#Connect the notebook with the database
# %sql postgresql://user:password@localhost:5432/postgres

# %% [markdown]
# ### 1. Select the first rows of the users and trades tables

# %%
# %%sql
# SELECT * FROM users LIMIT 10;
# Out:
#  * postgresql://user:***@localhost:5432/postgres
# 10 rows affected.
# [(101, 'Oslo', 'user101@example.com', datetime.datetime(2025, 7, 14, 14, 6, 9, 385643)),
#  (102, 'Barcelona', 'user102@example.com', datetime.datetime(2025, 7, 15, 14, 6, 9, 385643)),
#  (103, 'Amsterdam', 'user103@example.com', datetime.datetime(2025, 7, 16, 14, 6, 9, 385643)),
#  (104, 'Sevilla', 'user104@example.com', datetime.datetime(2025, 7, 17, 14, 6, 9, 385643)),
#  (105, 'Berlin', 'user105@example.com', datetime.datetime(2025, 7, 18, 14, 6, 9, 385643)),
#  (106, 'Paris', 'user106@example.com', datetime.datetime(2025, 7, 19, 14, 6, 9, 385643)),
#  (107, 'Rome', 'user107@example.com', datetime.datetime(2025, 7, 20, 14, 6, 9, 385643)),
#  (108, 'Lisbon', 'user108@example.com', datetime.datetime(2025, 7, 21, 14, 6, 9, 385643)),
#  (109, 'Madrid', 'user109@example.com', datetime.datetime(2025, 7, 22, 14, 6, 9, 385643)),
# ...

# %%
# %%sql
# SELECT * FROM trades LIMIT 10;
# Out:
#  * postgresql://user:***@localhost:5432/postgres
# 10 rows affected.
# [(1, 101, Decimal('49.99'), 10, 'impression', datetime.datetime(2025, 7, 14, 14, 6, 9, 390287)),
#  (2, 102, Decimal('75.50'), 5, 'click', datetime.datetime(2025, 7, 15, 14, 6, 9, 390287)),
#  (3, 103, Decimal('20.00'), 15, 'click', datetime.datetime(2025, 7, 16, 14, 6, 9, 390287)),
#  (4, 104, Decimal('100.00'), 8, 'impression', datetime.datetime(2025, 7, 17, 14, 6, 9, 390287)),
#  (5, 105, Decimal('60.25'), 20, 'click', datetime.datetime(2025, 7, 18, 14, 6, 9, 390287)),
#  (6, 106, Decimal('33.33'), 12, 'impression', datetime.datetime(2025, 7, 19, 14, 6, 9, 390287)),
#  (7, 101, Decimal('85.75'), 7, 'click', datetime.datetime(2025, 7, 20, 14, 6, 9, 390287)),
#  (8, 102, Decimal('42.10'), 18, 'impression', datetime.datetime(2025, 7, 21, 14, 6, 9, 390287)),
#  (9, 103, Decimal('55.55'), 9, 'click', datetime.datetime(2025, 7, 22, 14, 6, 9, 390287)),
# ...

# %% [markdown]
# ### 2. Find the total trade value (price * quantity) per user

# %%
# %%sql
# SELECT user_id, price, quantity, price * quantity as trade_value
# FROM trades;
# Out:
#  * postgresql://user:***@localhost:5432/postgres
# 50 rows affected.
# [(101, Decimal('49.99'), 10, Decimal('499.90')),
#  (102, Decimal('75.50'), 5, Decimal('377.50')),
#  (103, Decimal('20.00'), 15, Decimal('300.00')),
#  (104, Decimal('100.00'), 8, Decimal('800.00')),
#  (105, Decimal('60.25'), 20, Decimal('1205.00')),
#  (106, Decimal('33.33'), 12, Decimal('399.96')),
#  (101, Decimal('85.75'), 7, Decimal('600.25')),
#  (102, Decimal('42.10'), 18, Decimal('757.80')),
#  (103, Decimal('55.55'), 9, Decimal('499.95')),
#  (104, Decimal('99.99'), 11, Decimal('1099.89')),
#  (105, Decimal('44.44'), 14, Decimal('622.16')),
#  (106, Decimal('77.77'), 6, Decimal('466.62')),
#  (101, Decimal('23.45'), 13, Decimal('304.85')),
#  (102, Decimal('88.88'), 5, Decimal('444.40')),
#  (103, Decimal('66.66'), 17, Decimal('1133.22')),
#  (104, Decimal('31.11'), 19, Decimal('591.09')),
#  (105, Decimal('50.50'), 8, Decimal('404.00')),
#  (106, Decimal('45.45'), 12, Decimal('545.40')),
# ...

# %% [markdown]
# ### 2. List each user's email, city and corresponding trades (order_id, price, quantity, status).

# %%
# %%sql
#
# CREATE TABLE user_trades as
# SELECT u.user_id, u.city, u.email, u.signup_date,
#     t.order_id, t.price, t.quantity, t.status, t.timestamp
# FROM users u
# JOIN trades t on u.user_id = t.user_id;
# Out:
#  * postgresql://user:***@localhost:5432/postgres
# 50 rows affected.
# []

# %%
# %%sql
# SELECT * FROM user_trades
# Out:
#  * postgresql://user:***@localhost:5432/postgres
# 50 rows affected.
# [(101, 'Oslo', 'user101@example.com', datetime.datetime(2025, 7, 14, 14, 6, 9, 385643), 1, Decimal('49.99'), 10, 'impression', datetime.datetime(2025, 7, 14, 14, 6, 9, 390287)),
#  (102, 'Barcelona', 'user102@example.com', datetime.datetime(2025, 7, 15, 14, 6, 9, 385643), 2, Decimal('75.50'), 5, 'click', datetime.datetime(2025, 7, 15, 14, 6, 9, 390287)),
#  (103, 'Amsterdam', 'user103@example.com', datetime.datetime(2025, 7, 16, 14, 6, 9, 385643), 3, Decimal('20.00'), 15, 'click', datetime.datetime(2025, 7, 16, 14, 6, 9, 390287)),
#  (104, 'Sevilla', 'user104@example.com', datetime.datetime(2025, 7, 17, 14, 6, 9, 385643), 4, Decimal('100.00'), 8, 'impression', datetime.datetime(2025, 7, 17, 14, 6, 9, 390287)),
#  (105, 'Berlin', 'user105@example.com', datetime.datetime(2025, 7, 18, 14, 6, 9, 385643), 5, Decimal('60.25'), 20, 'click', datetime.datetime(2025, 7, 18, 14, 6, 9, 390287)),
# ...
