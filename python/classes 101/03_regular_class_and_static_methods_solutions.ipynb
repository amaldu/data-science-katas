# %% [markdown]
# ## 1. Create a class Employee with:
# - 2 class variables: num_of_emps = 0, raise_amt = 1.08. The variable num_of_emps has to increase by 1 every time the class is instantiated
# - constructor with the attributes: first, last, email, salary. email is created as first.last@example.com.
# - method called full_name that returns first and last name separated by a space
# - method called apply_raise that returns the update salary as the product of the salary by the raise_amt
#
# Instantiate every required class under emp_1 and emp_2 in each step from now on

# %%
class Employee:
    num_of_emps = 0
    raise_amt = 1.08
    def __init__ (self, first, last, salary):
        self.first = first
        self.last = last
        self.email = f"{first.lower()}.{last.lower()}@example.com"
        self.salary = salary
        Employee.num_of_emps += 1
        
    def full_name(self):
        return f"{self.first} {self.last}"
    
    def apply_raise(self):
        self.salary =  int(self.salary * self.raise_amt)
        return self.salary
    
emp_1 = Employee("Martin", "Schmidt", 50000)
emp_2 = Employee("Maria", "Johnson", 60000)

# %% [markdown]
# ### The methods we have seen so far are called "regular methods". Regular methods in a class automatically take the instance as the first argument and by convention we were calling this (self).
#
# ### Class methods are bounded to the class, not the instance of the class. They can access and modify class state that applies accross all instance of the class. To define a class method we need:
#
#      1. The @classmethod decorator
#      2. The first parameter of a class method is always cls, which refers to the class itself, not an object instance (self).
#
# ## 2. Rewrite the class by adding an empty class method inside called set_raised_amt, as attributes add the class itself and "amount".

# %%
class Employee:
    num_of_emps = 0
    raise_amt = 1.08
    def __init__ (self, first, last, salary):
        self.first = first
        self.last = last
        self.email = f"{first.lower()}.{last.lower()}@emaple.com"
        self.salary = salary
        Employee.num_of_emps += 1
        
    def full_name(self):
        return f"{self.first} {self.last}"
    
    def apply_raise(self):
        self.salary =  int(self.salary * self.raise_amt)
        return self.salary
    
    @classmethod
    def set_raised_amt(cls, amount):
        pass
    
    
emp_1 = Employee("Martin", "Schmidt", 50000)
emp_2 = Employee("Maria", "Johnson", 60000)

# %% [markdown]
# ## 3. Fill the class method "set_raised_amt" with code to modify the class variable named "raise_amt" set at the begining. Print:
# - class raise_amt
# - emp_1 raise_amt
# - emp_2 raise_amt
#
# Then use the class method to modify raise_amt value to an increase of 12% and print:
#
# - class raise_amt
# - emp_1 raise_amt
# - emp_2 raise_amt

# %%
class Employee:
    num_of_emps = 0
    raise_amt = 1.08
    def __init__ (self, first, last, salary):
        self.first = first
        self.last = last
        self.email = f"{first.lower()}.{last.lower()}@emaple.com"
        self.salary = salary
        Employee.num_of_emps += 1
        
    def full_name(self):
        return f"{self.first} {self.last}"
    
    def apply_raise(self):
        self.salary =  int(self.salary * self.raise_amt)
        return self.salary
    
    @classmethod
    def set_raised_amt(cls, amount):
        cls.raise_amt = amount
    
    
emp_1 = Employee("Martin", "Schmidt", 50000)
emp_2 = Employee("Maria", "Johnson", 60000)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)

Employee.set_raised_amt(1.12)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)

# %% [markdown]
# ## 4. Class method as alternative constructions use case:
#
# The data we are receiving in the company has chaged and it does not come in string format separated by hyphens:
#
#
# * emp_str_1 = "John-Doe-60000"
# * emp_str_2 = "Jane-Smith-50000"
# * emp_str_3 = "Mathilda-Brucks-90000"
#
# We don't want to parse them every time before using our class. Create a class method that manages this new format and creates new employees.
#
# Create the three new employees and print:
# - emp_4 full name
# - emp_5 email
# - emp_6 salary

# %%
class Employee:
    num_of_emps = 0
    raise_amt = 1.08
    def __init__ (self, first, last, salary):
        self.first = first
        self.last = last
        self.email = f"{first.lower()}.{last.lower()}@emaple.com"
        self.salary = salary
        Employee.num_of_emps += 1
        
    def full_name(self):
        return f"{self.first} {self.last}"
    
    def apply_raise(self):
        self.salary =  int(self.salary * self.raise_amt)
        return self.salary
    
    @classmethod
    def set_raised_amt(cls, amount):
        cls.raise_amt = amount
        
    @classmethod
    def from_string(cls, emp_str):
        first, last, salary = emp_str.split("-")
        return cls(first, last, int(salary))
    
emp_str_1 = "John-Doe-60000"
emp_str_2 = "Jane-Smith-50000"
emp_str_3 = "Mathilda-Brucks-90000"

emp_4 = Employee.from_string(emp_str_1)
emp_5 = Employee.from_string(emp_str_2)
emp_6 = Employee.from_string(emp_str_3)

print(f"The emp_4 full name is {emp_4.full_name()}")
print(f"The emp_5 email address is {emp_5.email}")
print(f"The emp_6 has a new salary of {emp_6.apply_raise()}")

# %% [markdown]
# ###  Static methods don't pass the instance nor the class as the first argument of the method. They behave like regular functions but we include them inside of our classes because they have some logical connection with the class. They are used to keep code organized inside the class namespace.
#
# ## 5.Create a simple function inside the class that would take in a date and return whether or not that was a work day.
#
# This function has a logical connection to Employee but it does not depend on any instance or class variable, that's why they are called static method

# %%
class Employee:
    num_of_emps = 0
    raise_amt = 1.08
    def __init__ (self, first, last, salary):
        self.first = first
        self.last = last
        self.email = f"{first.lower()}.{last.lower()}@emaple.com"
        self.salary = salary
        Employee.num_of_emps += 1
        
    def full_name(self):
        return f"{self.first} {self.last}"
    
    def apply_raise(self):
        self.salary =  int(self.salary * self.raise_amt)
        return self.salary
    
    @classmethod
    def set_raised_amt(cls, amount):
        cls.raise_amt = amount
        
    @classmethod
    def from_string(cls, emp_str):
        first, last, salary = emp_str.split("-")
        return cls(first, last, int(salary))
    
    @staticmethod
    def is_workday(day): # Monday is equal to 0 and Sunday is equal to 6
        if day.weekday() == 5 or day.weekday() == 6:
            return False
        return True

import datetime
my_date = datetime.date(2023, 8, 10)

print(Employee.is_workday(my_date))
